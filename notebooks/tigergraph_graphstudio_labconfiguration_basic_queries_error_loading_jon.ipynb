# %%
# FETCH PACKAGES
# !pip install pyTigerGraph
# !pip install python-dotenv
import pyTigerGraph as tg
from dotenv import load_dotenv
import os
import pandas as pd
import json
import requests
# Out:
# Collecting pyTigerGraph
#   Downloading pyTigerGraph-1.6.1-py3-none-any.whl (267 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 2.2 MB/s eta 0:00:00
# Collecting validators (from pyTigerGraph)
#   Downloading validators-0.28.1-py3-none-any.whl (39 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pyTigerGraph) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pyTigerGraph) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pyTigerGraph) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pyTigerGraph) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pyTigerGraph) (2024.2.2)
# Installing collected packages: validators, pyTigerGraph
# Successfully installed pyTigerGraph-1.6.1 validators-0.28.1
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
#GRAB DATA FILES. CREATE DATA FRAMES FROM .CSV FILES AND PREPARE FOR UPSERTION
# !git clone https://github.com/ArshdeepKaur/knowledge_graph_using_tigergraph

#VERTEX: movie
df_movies = pd.read_csv("/content/knowledge_graph_using_tigergraph/data/movies.csv", sep=";")
null_df = df_movies[df_movies.isna().any(axis=1)]
print(null_df)
df_movies['tagline']  = df_movies['tagline'].fillna('') #tagline (str) has NaN
print(df_movies.info())
print(df_movies.head(2))

#VERTEX: person
dtype_dict = {
    'name': str,
    'born': int}
df_actors = pd.read_csv("/content/knowledge_graph_using_tigergraph/data/actors.csv", sep=";")
null_df = df_actors[df_actors.isna().any(axis=1)]
print(null_df)
df_actors['born'] = df_actors['born'].fillna(0) #born (int) has NaN
df_actors = df_actors.astype(dtype_dict)
print(df_actors.info())
print(df_actors.head(2))

#EDGE ACTED_IN
df_acted_in = pd.read_csv("/content/knowledge_graph_using_tigergraph/data/acted_in.csv", sep=";")
print(df_acted_in.info())
print(df_acted_in.head(2))
# Out:
# Cloning into 'knowledge_graph_using_tigergraph'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 19 (delta 4), reused 15 (delta 3), pack-reused 0
# Receiving objects: 100% (19/19), 9.91 KiB | 3.30 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
#                      title tagline  released
# 33  Something's Gotta Give     NaN      2003
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     38 non-null     object
#  1   tagline   38 non-null     object
#  2   released  38 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ KB
# None
#                  title                    tagline  released
# 0           The Matrix  Welcome to the Real World      1999
# 1  The Matrix Reloaded             Free your mind      2003
#                  name  born
# 103     Naomie Harris   NaN
# 129       Paul Blythe   NaN
# 130      Angela Scope   NaN
# 131  Jessica Thompson   NaN
# 132    James Thompson   NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    133 non-null    object
#  1   born    133 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None
#                name  born
# 0      Keanu Reeves  1964
# 1  Carrie-Anne Moss  1967
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   actor   172 non-null    object
#  1   movie   172 non-null    object
# dtypes: object(2)
# memory usage: 2.8+ KB
# None
#           actor       movie
# 0   Emil Eifrem  The Matrix
# 1  Hugo Weaving  The Matrix

# %%
#CREATE HOST STRING USING SUBDOMAIN
load_dotenv('/content/env', override=True)

TG_IP = os.getenv('TG_IP')
TG_CLUSTER = os.getenv('TG_CLUSTER')
TG_SUBDOMAIN = os.getenv('TG_SUBDOMAIN')
TG_DOMAIN=f"{TG_SUBDOMAIN}.i.tgcloud.io"
TG_SUBNET = os.getenv('TG_SUBNET')
TG_USERNAME = os.getenv('TG_USERNAME')
TG_PASSWORD = os.getenv('TG_PASSWORD')
TG_GRAPH = os.getenv('TG_GRAPH')
host_string = f"https://{TG_DOMAIN}"

# %%
# CONNECT TO TigerGraph CLOUD
conn = tg.TigerGraphConnection(host=host_string, username=TG_USERNAME, password=TG_PASSWORD)
print("Connected")
print(conn)
# Out:
# Connected
# <pyTigerGraph.pyTigerGraph.TigerGraphConnection object at 0x7c3a42926410>

# %%
#DANGEROUS! - CLEAR THE SCHEMA AND GRAPH
conn.gsql('''
USE GLOBAL
DROP ALL
''')
# Out:
# 'Dropping all, about 1 minute ...\nAbort all active loading jobs\nTry to abort all loading jobs on graph movie_graph, it may take a while ...\nResetting GPE...\nSuccessfully reset GPE and GSE\nStopping GPE GSE\nSuccessfully stopped GPE GSE in 0.005 seconds\nClearing graph store...\nSuccessfully cleared graph store\nStarting GPE GSE RESTPP\nSuccessfully started GPE GSE RESTPP in 0.078 seconds\nEverything is dropped.'

# %%
#CREATE VERTICES & EDGES
conn.gsql('''
USE GLOBAL
CREATE VERTEX person (
  PRIMARY_ID name STRING, born INT
)
WITH primary_id_as_attribute="true"

CREATE VERTEX movie (
  PRIMARY_ID title STRING, tagline STRING, released INT
)
WITH primary_id_as_attribute="true"

CREATE UNDIRECTED EDGE ACTED_IN (FROM person, TO movie)

CREATE UNDIRECTED EDGE DIRECTED (FROM person, TO movie)

CREATE UNDIRECTED EDGE FRIEND (FROM person, TO person)
''')
# Out:
# 'Successfully created vertex types: [person].\nSuccessfully created vertex types: [movie].\nSuccessfully created edge types: [ACTED_IN].\nSuccessfully created edge types: [DIRECTED].\nSuccessfully created edge types: [FRIEND].'

# %%
#CREATE GRAPH
conn.gsql('''
CREATE GRAPH movie_graph(person, movie, ACTED_IN, DIRECTED, FRIEND)
''')
# Out:
# 'Stopping GPE GSE RESTPP\nSuccessfully stopped GPE GSE RESTPP in 31.616 seconds\nStarting GPE GSE RESTPP\nSuccessfully started GPE GSE RESTPP in 0.081 seconds\nThe graph movie_graph is created.'

# %%
#FETCH ACCESS TOKEN
conn.graphname = TG_GRAPH
secret = conn.createSecret()
token = conn.getToken(secret, setToken=True)

print(conn, conn.graphname)

#VERIFY THE SCHEMA
print(conn.getSchema())

print(conn.gsql("LS"))
print(conn.getVertexTypes())
print(conn.getEdgeTypes())
# Out:
# <pyTigerGraph.pyTigerGraph.TigerGraphConnection object at 0x7c3a42926410> movie_graph
# {'GraphName': 'movie_graph', 'VertexTypes': [{'Config': {'STATS': 'OUTDEGREE_BY_EDGETYPE', 'PRIMARY_ID_AS_ATTRIBUTE': True}, 'Attributes': [{'AttributeType': {'Name': 'INT'}, 'AttributeName': 'born'}], 'PrimaryId': {'AttributeType': {'Name': 'STRING'}, 'PrimaryIdAsAttribute': True, 'AttributeName': 'name'}, 'Name': 'person'}, {'Config': {'STATS': 'OUTDEGREE_BY_EDGETYPE', 'PRIMARY_ID_AS_ATTRIBUTE': True}, 'Attributes': [{'AttributeType': {'Name': 'STRING'}, 'AttributeName': 'tagline'}, {'AttributeType': {'Name': 'INT'}, 'AttributeName': 'released'}], 'PrimaryId': {'AttributeType': {'Name': 'STRING'}, 'PrimaryIdAsAttribute': True, 'AttributeName': 'title'}, 'Name': 'movie'}], 'EdgeTypes': [{'IsDirected': False, 'ToVertexTypeName': 'movie', 'Config': {}, 'Attributes': [], 'FromVertexTypeName': 'person', 'Name': 'ACTED_IN'}, {'IsDirected': False, 'ToVertexTypeName': 'movie', 'Config': {}, 'Attributes': [], 'FromVertexTypeName': 'person', 'Name': 'DIRECTED'}, {'IsDirected': False, 'ToVertexTypeName': 'person', 'Config': {}, 'Attributes': [], 'FromVertexTypeName': 'person', 'Name': 'FRIEND'}], 'UDTs': []}
# ---- Global vertices, edges, and all graphs
# Vertex Types:
#   - VERTEX person(PRIMARY_ID name STRING, born INT) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
#   - VERTEX movie(PRIMARY_ID title STRING, tagline STRING, released INT) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
# Edge Types:
#   - UNDIRECTED EDGE ACTED_IN(FROM person, TO movie)
#   - UNDIRECTED EDGE DIRECTED(FROM person, TO movie)
#   - UNDIRECTED EDGE FRIEND(FROM person, TO person)
#
# Graphs:
#   - Graph movie_graph(person:v, movie:v, ACTED_IN:e, DIRECTED:e, FRIEND:e)
# Jobs:
#
#
# JSON API version: v2
# Syntax version: v2
#
# ['person', 'movie']
# ['ACTED_IN', 'DIRECTED', 'FRIEND']

# %%
#UPSERT DATA INTO VERTEX: movie
v_movies = conn.upsertVertexDataFrame(df_movies, 'movie', v_id='title', attributes={'title':'title', 'tagline': 'tagline', 'released': 'released'})
print(str(v_movies) + " movie VERTICES upserted")
# Out:
# 38 movie VERTICES upserted

# %%
#UPSERT DATA INTO VERTEX: person
v_actors = conn.upsertVertexDataFrame(df_actors, 'person', v_id='name', attributes={'name':'name', 'born': 'born'})
print(str(v_actors) + " person VERTICES upserted")
# Out:
# 133 person VERTICES upserted

# %%
#UPSERT DATA INTO EDGE: ACTED_IN
e_ACTED_IN = conn.upsertEdgeDataFrame(df=df_acted_in, sourceVertexType='person', edgeType="ACTED_IN", targetVertexType='movie', from_id='actor', to_id='movie', attributes={}
)
print(str(e_ACTED_IN) + " ACTED_IN EDGES upserted")
# Out:
# 172 ACTED_IN EDGES upserted

# %%
# SIMPLE SELECT QUERY
query = '''
    USE GRAPH movie_graph
    DROP QUERY view_all_movies

    CREATE QUERY view_all_movies () {
        result = SELECT m FROM movie:m;
        PRINT result[result.title, result.tagline];
    }
    INSTALL QUERY view_all_movies
    '''
results = conn.gsql(query)
print (results)

results = conn.runInstalledQuery("view_all_movies")
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "result": [
#       {
#         "v_id": "A Few Good Men",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "A Few Good Men",
#           "result.tagline": "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth."
#         }
#       },
#       {
#         "v_id": "Charlie Wilson's War",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Charlie Wilson's War",
#           "result.tagline": "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire."
#         }
#       },
#       {
#         "v_id": "Cast Away",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Cast Away",
#           "result.tagline": "At the edge of the world, his journey begins."
#         }
#       },
#       {
#         "v_id": "The Matrix Reloaded",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Matrix Reloaded",
#           "result.tagline": "Free your mind"
#         }
#       },
#       {
#         "v_id": "The Devil's Advocate",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Devil's Advocate",
#           "result.tagline": "Evil has its winning ways"
#         }
#       },
#       {
#         "v_id": "The Birdcage",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Birdcage",
#           "result.tagline": "Come as you are"
#         }
#       },
#       {
#         "v_id": "The Polar Express",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Polar Express",
#           "result.tagline": "This Holiday Season... Believe"
#         }
#       },
#       {
#         "v_id": "Speed Racer",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Speed Racer",
#           "result.tagline": "Speed has no limits"
#         }
#       },
#       {
#         "v_id": "Jerry Maguire",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Jerry Maguire",
#           "result.tagline": "The rest of his life begins now."
#         }
#       },
#       {
#         "v_id": "Top Gun",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Top Gun",
#           "result.tagline": "I feel the need, the need for speed."
#         }
#       },
#       {
#         "v_id": "The Replacements",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Replacements",
#           "result.tagline": "Pain heals, Chicks dig scars... Glory lasts forever"
#         }
#       },
#       {
#         "v_id": "Hoffa",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Hoffa",
#           "result.tagline": "He didn't want law. He wanted justice."
#         }
#       },
#       {
#         "v_id": "Apollo 13",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Apollo 13",
#           "result.tagline": "Houston, we have a problem."
#         }
#       },
#       {
#         "v_id": "Sleepless in Seattle",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Sleepless in Seattle",
#           "result.tagline": "What if someone you never met, someone you never saw, someone you never knew was the only someone for you?"
#         }
#       },
#       {
#         "v_id": "The Green Mile",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Green Mile",
#           "result.tagline": "Walk a mile you'll never forget."
#         }
#       },
#       {
#         "v_id": "Cloud Atlas",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Cloud Atlas",
#           "result.tagline": "Everything is connected"
#         }
#       },
#       {
#         "v_id": "Frost/Nixon",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Frost/Nixon",
#           "result.tagline": "400 million people were waiting for the truth."
#         }
#       },
#       {
#         "v_id": "V for Vendetta",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "V for Vendetta",
#           "result.tagline": "Freedom! Forever!"
#         }
#       },
#       {
#         "v_id": "What Dreams May Come",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "What Dreams May Come",
#           "result.tagline": "After life there is more. The end is just the beginning."
#         }
#       },
#       {
#         "v_id": "As Good as It Gets",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "As Good as It Gets",
#           "result.tagline": "A comedy from the heart that goes for the throat."
#         }
#       },
#       {
#         "v_id": "Bicentennial Man",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Bicentennial Man",
#           "result.tagline": "One robot's 200 year journey to become an ordinary man."
#         }
#       },
#       {
#         "v_id": "The Matrix",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Matrix",
#           "result.tagline": "Welcome to the Real World"
#         }
#       },
#       {
#         "v_id": "Stand By Me",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Stand By Me",
#           "result.tagline": "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of."
#         }
#       },
#       {
#         "v_id": "Johnny Mnemonic",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Johnny Mnemonic",
#           "result.tagline": "The hottest data on earth. In the coolest head in town"
#         }
#       },
#       {
#         "v_id": "Joe Versus the Volcano",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Joe Versus the Volcano",
#           "result.tagline": "A story of love, lava and burning desire."
#         }
#       },
#       {
#         "v_id": "One Flew Over the Cuckoo's Nest",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "One Flew Over the Cuckoo's Nest",
#           "result.tagline": "If he's crazy, what does that make you?"
#         }
#       },
#       {
#         "v_id": "A League of Their Own",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "A League of Their Own",
#           "result.tagline": "Once in a lifetime you get a chance to do something different."
#         }
#       },
#       {
#         "v_id": "Twister",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Twister",
#           "result.tagline": "Don't Breathe. Don't Look Back."
#         }
#       },
#       {
#         "v_id": "When Harry Met Sally",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "When Harry Met Sally",
#           "result.tagline": "Can two friends sleep together and still love each other in the morning?"
#         }
#       },
#       {
#         "v_id": "The Da Vinci Code",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Da Vinci Code",
#           "result.tagline": "Break The Codes"
#         }
#       },
#       {
#         "v_id": "Snow Falling on Cedars",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Snow Falling on Cedars",
#           "result.tagline": "First loves last. Forever."
#         }
#       },
#       {
#         "v_id": "You've Got Mail",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "You've Got Mail",
#           "result.tagline": "At odds in life... in love on-line."
#         }
#       },
#       {
#         "v_id": "That Thing You Do",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "That Thing You Do",
#           "result.tagline": "In every life there comes a time when that thing you dream becomes that thing you do"
#         }
#       },
#       {
#         "v_id": "Something's Gotta Give",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Something's Gotta Give",
#           "result.tagline": ""
#         }
#       },
#       {
#         "v_id": "RescueDawn",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "RescueDawn",
#           "result.tagline": "Based on the extraordinary true story of one man's fight for freedom"
#         }
#       },
#       {
#         "v_id": "Unforgiven",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Unforgiven",
#           "result.tagline": "It's a hell of a thing, killing a man"
#         }
#       },
#       {
#         "v_id": "The Matrix Revolutions",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Matrix Revolutions",
#           "result.tagline": "Everything that has a beginning has an end"
#         }
#       },
#       {
#         "v_id": "Ninja Assassin",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Ninja Assassin",
#           "result.tagline": "Prepare to enter a secret world of assassins"
#         }
#       }
#     ]
#   }
# ]

# %%
# SIMPLE 1-HOP PARAMETERIZED QUERY
query = '''
    USE GRAPH movie_graph
    DROP QUERY select_all_movies_for_person
    CREATE QUERY select_all_movies_for_person (VERTEX<person> p) {
        start = {p};
        result = SELECT tgt
            FROM start:s -(ACTED_IN:e)- movie:tgt;
        PRINT result[result.title];
    }
INSTALL QUERY select_all_movies_for_person
'''

results = conn.gsql(query)
print(results)

parameters = {
    "p": "Tom Hanks"
}
results = conn.runInstalledQuery("select_all_movies_for_person", params=parameters)
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "result": [
#       {
#         "v_id": "Charlie Wilson's War",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Charlie Wilson's War"
#         }
#       },
#       {
#         "v_id": "Cast Away",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Cast Away"
#         }
#       },
#       {
#         "v_id": "The Polar Express",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Polar Express"
#         }
#       },
#       {
#         "v_id": "Apollo 13",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Apollo 13"
#         }
#       },
#       {
#         "v_id": "A League of Their Own",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "A League of Their Own"
#         }
#       },
#       {
#         "v_id": "Sleepless in Seattle",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Sleepless in Seattle"
#         }
#       },
#       {
#         "v_id": "The Green Mile",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Green Mile"
#         }
#       },
#       {
#         "v_id": "Cloud Atlas",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Cloud Atlas"
#         }
#       },
#       {
#         "v_id": "The Da Vinci Code",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "The Da Vinci Code"
#         }
#       },
#       {
#         "v_id": "You've Got Mail",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "You've Got Mail"
#         }
#       },
#       {
#         "v_id": "Joe Versus the Volcano",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "Joe Versus the Volcano"
#         }
#       },
#       {
#         "v_id": "That Thing You Do",
#         "v_type": "movie",
#         "attributes": {
#           "result.title": "That Thing You Do"
#         }
#       }
#     ]
#   }
# ]

# %%
# 2-HOP PARAMETERIZED QUERY WITH ACCUMULATORS
query = '''
USE GRAPH movie_graph

DROP QUERY movies_of_costars

CREATE QUERY movies_of_costars (VERTEX<person> p, INT current_year = 2024) {
    OrAccum  @visited = FALSE;
    SumAccum <INT> @@count_movies;
    SumAccum <INT> @@count_costars;
    AvgAccum @@avg_age;
    ListAccum<STRING> @movies;
    ListAccum<STRING> @costars;

    start = {p};

    first_neighbors = SELECT tgt_m
        FROM start:s -(ACTED_IN:e)- movie:tgt_m
        ACCUM tgt_m.@visited += TRUE, s.@visited += TRUE, tgt_m.@movies += tgt_m.title
        POST-ACCUM (tgt_m) @@count_movies += 1;

    second_neighbors = SELECT tgt_p
        FROM person:tgt_p -(:e)- first_neighbors
        WHERE tgt_p.@visited == FALSE
        POST-ACCUM (tgt_p) @@count_costars += 1, @@avg_age += (current_year - tgt_p.born), tgt_p.@costars += tgt_p.name;

    PRINT "titles";
    PRINT first_neighbors[first_neighbors.title];
    PRINT "titles using @movies accumulator";
    PRINT first_neighbors[first_neighbors.@movies];
    PRINT "costars";
    PRINT second_neighbors[second_neighbors.name];
    PRINT "costars using @costars accumulator";
    PRINT second_neighbors[second_neighbors.@costars];
    PRINT "count of movies";
    PRINT @@count_movies;
    PRINT "count of costars";
    PRINT @@count_costars;
    PRINT "average age of costars";
    PRINT @@avg_age;
}

INSTALL QUERY movies_of_costars
'''

results = conn.gsql(query)
print(results)

parameters = {
    "p": "Tom Hanks"
}
results = conn.runInstalledQuery("movies_of_costars", params=parameters)
print(json.dumps(results, indent=2))
# Out:
# Using graph 'movie_graph'
# Successfully dropped queries on the graph 'movie_graph': [movies_of_costars].
# Warning in a transformed block of query movies_of_costars (WARN-2): line 25, col 35
# unsatisfiable pattern _>
# Warning in a transformed block of query movies_of_costars (WARN-2): line 25, col 38
# unsatisfiable pattern <_
# Warning in a transformed block of query movies_of_costars (WARN-7): line 28, col 1
# Non-binding POST-ACCUM clauses will be deprecated soon. Please rewrite the
# clause as: POST-ACCUM (selectAlias) ...
# Successfully created queries: [movies_of_costars].
# Start installing queries, about 1 minute ...
# movies_of_costars query: curl -X GET 'https://127.0.0.1:9000/query/movie_graph/movies_of_costars?p=VALUE&[current_year=VALUE]'. Add -H "Authorization: Bearer TOKEN" if authentication is enabled.
# Select 'm1' as compile server, now connecting ...
# Node 'm1' is prepared as compile server.
#
# [                                                                                     ] 0% (0/1)
# [                                                                                     ] 0% (0/1)
# [=================================================================================    ] 95% (0/1)
# [=====================================================================================] 100% (1/1)
# Query installation finished.
# [
#   {
#     "\"titles\"": "titles"
#   },
#   {
#     "first_neighbors": [
#       {
#         "v_id": "Charlie Wilson's War",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "Charlie Wilson's War"
#         }
#       },
#       {
#         "v_id": "Cast Away",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "Cast Away"
#         }
#       },
#       {
#         "v_id": "The Polar Express",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "The Polar Express"
#         }
#       },
#       {
#         "v_id": "Apollo 13",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "Apollo 13"
#         }
#       },
#       {
#         "v_id": "Sleepless in Seattle",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "Sleepless in Seattle"
#         }
#       },
#       {
#         "v_id": "The Green Mile",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "The Green Mile"
#         }
#       },
#       {
#         "v_id": "Cloud Atlas",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "Cloud Atlas"
#         }
#       },
#       {
#         "v_id": "That Thing You Do",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "That Thing You Do"
#         }
#       },
#       {
#         "v_id": "The Da Vinci Code",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "The Da Vinci Code"
#         }
#       },
#       {
#         "v_id": "You've Got Mail",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "You've Got Mail"
#         }
#       },
#       {
#         "v_id": "Joe Versus the Volcano",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "Joe Versus the Volcano"
#         }
#       },
#       {
#         "v_id": "A League of Their Own",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.title": "A League of Their Own"
#         }
#       }
#     ]
#   },
#   {
#     "\"titles using @movies accumulator\"": "titles using @movies accumulator"
#   },
#   {
#     "first_neighbors": [
#       {
#         "v_id": "Charlie Wilson's War",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "Charlie Wilson's War"
#           ]
#         }
#       },
#       {
#         "v_id": "Cast Away",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "Cast Away"
#           ]
#         }
#       },
#       {
#         "v_id": "The Polar Express",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "The Polar Express"
#           ]
#         }
#       },
#       {
#         "v_id": "Apollo 13",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "Apollo 13"
#           ]
#         }
#       },
#       {
#         "v_id": "A League of Their Own",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "A League of Their Own"
#           ]
#         }
#       },
#       {
#         "v_id": "Sleepless in Seattle",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "Sleepless in Seattle"
#           ]
#         }
#       },
#       {
#         "v_id": "The Green Mile",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "The Green Mile"
#           ]
#         }
#       },
#       {
#         "v_id": "Cloud Atlas",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "Cloud Atlas"
#           ]
#         }
#       },
#       {
#         "v_id": "That Thing You Do",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "That Thing You Do"
#           ]
#         }
#       },
#       {
#         "v_id": "The Da Vinci Code",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "The Da Vinci Code"
#           ]
#         }
#       },
#       {
#         "v_id": "You've Got Mail",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "You've Got Mail"
#           ]
#         }
#       },
#       {
#         "v_id": "Joe Versus the Volcano",
#         "v_type": "movie",
#         "attributes": {
#           "first_neighbors.@movies": [
#             "Joe Versus the Volcano"
#           ]
#         }
#       }
#     ]
#   },
#   {
#     "\"costars\"": "costars"
#   },
#   {
#     "second_neighbors": [
#       {
#         "v_id": "James Cromwell",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "James Cromwell"
#         }
#       },
#       {
#         "v_id": "Patricia Clarkson",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Patricia Clarkson"
#         }
#       },
#       {
#         "v_id": "Audrey Tautou",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Audrey Tautou"
#         }
#       },
#       {
#         "v_id": "Steve Zahn",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Steve Zahn"
#         }
#       },
#       {
#         "v_id": "Dave Chappelle",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Dave Chappelle"
#         }
#       },
#       {
#         "v_id": "Lori Petty",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Lori Petty"
#         }
#       },
#       {
#         "v_id": "Madonna",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Madonna"
#         }
#       },
#       {
#         "v_id": "Ed Harris",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Ed Harris"
#         }
#       },
#       {
#         "v_id": "Meg Ryan",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Meg Ryan"
#         }
#       },
#       {
#         "v_id": "Bill Pullman",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Bill Pullman"
#         }
#       },
#       {
#         "v_id": "Victor Garber",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Victor Garber"
#         }
#       },
#       {
#         "v_id": "Sam Rockwell",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Sam Rockwell"
#         }
#       },
#       {
#         "v_id": "Nathan Lane",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Nathan Lane"
#         }
#       },
#       {
#         "v_id": "Julia Roberts",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Julia Roberts"
#         }
#       },
#       {
#         "v_id": "Charlize Theron",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Charlize Theron"
#         }
#       },
#       {
#         "v_id": "Paul Bettany",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Paul Bettany"
#         }
#       },
#       {
#         "v_id": "Bonnie Hunt",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Bonnie Hunt"
#         }
#       },
#       {
#         "v_id": "Greg Kinnear",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Greg Kinnear"
#         }
#       },
#       {
#         "v_id": "Geena Davis",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Geena Davis"
#         }
#       },
#       {
#         "v_id": "Helen Hunt",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Helen Hunt"
#         }
#       },
#       {
#         "v_id": "Philip Seymour Hoffman",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Philip Seymour Hoffman"
#         }
#       },
#       {
#         "v_id": "Parker Posey",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Parker Posey"
#         }
#       },
#       {
#         "v_id": "Ian McKellen",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Ian McKellen"
#         }
#       },
#       {
#         "v_id": "Liv Tyler",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Liv Tyler"
#         }
#       },
#       {
#         "v_id": "Kevin Bacon",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Kevin Bacon"
#         }
#       },
#       {
#         "v_id": "Hugo Weaving",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Hugo Weaving"
#         }
#       },
#       {
#         "v_id": "Jim Broadbent",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Jim Broadbent"
#         }
#       },
#       {
#         "v_id": "Rita Wilson",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Rita Wilson"
#         }
#       },
#       {
#         "v_id": "Rosie O'Donnell",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Rosie O'Donnell"
#         }
#       },
#       {
#         "v_id": "Gary Sinise",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Gary Sinise"
#         }
#       },
#       {
#         "v_id": "Michael Clarke Duncan",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Michael Clarke Duncan"
#         }
#       },
#       {
#         "v_id": "Bill Paxton",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Bill Paxton"
#         }
#       },
#       {
#         "v_id": "Halle Berry",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "Halle Berry"
#         }
#       },
#       {
#         "v_id": "David Morse",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.name": "David Morse"
#         }
#       }
#     ]
#   },
#   {
#     "\"costars using @costars accumulator\"": "costars using @costars accumulator"
#   },
#   {
#     "second_neighbors": [
#       {
#         "v_id": "James Cromwell",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "James Cromwell"
#           ]
#         }
#       },
#       {
#         "v_id": "Patricia Clarkson",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Patricia Clarkson"
#           ]
#         }
#       },
#       {
#         "v_id": "Audrey Tautou",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Audrey Tautou"
#           ]
#         }
#       },
#       {
#         "v_id": "Steve Zahn",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Steve Zahn"
#           ]
#         }
#       },
#       {
#         "v_id": "Dave Chappelle",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Dave Chappelle"
#           ]
#         }
#       },
#       {
#         "v_id": "Lori Petty",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Lori Petty"
#           ]
#         }
#       },
#       {
#         "v_id": "Madonna",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Madonna"
#           ]
#         }
#       },
#       {
#         "v_id": "Charlize Theron",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Charlize Theron"
#           ]
#         }
#       },
#       {
#         "v_id": "Paul Bettany",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Paul Bettany"
#           ]
#         }
#       },
#       {
#         "v_id": "Ed Harris",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Ed Harris"
#           ]
#         }
#       },
#       {
#         "v_id": "Sam Rockwell",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Sam Rockwell"
#           ]
#         }
#       },
#       {
#         "v_id": "Nathan Lane",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Nathan Lane"
#           ]
#         }
#       },
#       {
#         "v_id": "Meg Ryan",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Meg Ryan"
#           ]
#         }
#       },
#       {
#         "v_id": "Kevin Bacon",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Kevin Bacon"
#           ]
#         }
#       },
#       {
#         "v_id": "Julia Roberts",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Julia Roberts"
#           ]
#         }
#       },
#       {
#         "v_id": "David Morse",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "David Morse"
#           ]
#         }
#       },
#       {
#         "v_id": "Hugo Weaving",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Hugo Weaving"
#           ]
#         }
#       },
#       {
#         "v_id": "Geena Davis",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Geena Davis"
#           ]
#         }
#       },
#       {
#         "v_id": "Bill Pullman",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Bill Pullman"
#           ]
#         }
#       },
#       {
#         "v_id": "Victor Garber",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Victor Garber"
#           ]
#         }
#       },
#       {
#         "v_id": "Michael Clarke Duncan",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Michael Clarke Duncan"
#           ]
#         }
#       },
#       {
#         "v_id": "Bill Paxton",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Bill Paxton"
#           ]
#         }
#       },
#       {
#         "v_id": "Helen Hunt",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Helen Hunt"
#           ]
#         }
#       },
#       {
#         "v_id": "Bonnie Hunt",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Bonnie Hunt"
#           ]
#         }
#       },
#       {
#         "v_id": "Jim Broadbent",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Jim Broadbent"
#           ]
#         }
#       },
#       {
#         "v_id": "Philip Seymour Hoffman",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Philip Seymour Hoffman"
#           ]
#         }
#       },
#       {
#         "v_id": "Greg Kinnear",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Greg Kinnear"
#           ]
#         }
#       },
#       {
#         "v_id": "Parker Posey",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Parker Posey"
#           ]
#         }
#       },
#       {
#         "v_id": "Ian McKellen",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Ian McKellen"
#           ]
#         }
#       },
#       {
#         "v_id": "Liv Tyler",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Liv Tyler"
#           ]
#         }
#       },
#       {
#         "v_id": "Rosie O'Donnell",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Rosie O'Donnell"
#           ]
#         }
#       },
#       {
#         "v_id": "Halle Berry",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Halle Berry"
#           ]
#         }
#       },
#       {
#         "v_id": "Rita Wilson",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Rita Wilson"
#           ]
#         }
#       },
#       {
#         "v_id": "Gary Sinise",
#         "v_type": "person",
#         "attributes": {
#           "second_neighbors.@costars": [
#             "Gary Sinise"
#           ]
#         }
#       }
#     ]
#   },
#   {
#     "\"count of movies\"": "count of movies"
#   },
#   {
#     "@@count_movies": 13
#   },
#   {
#     "\"count of costars\"": "count of costars"
#   },
#   {
#     "@@count_costars": 34
#   },
#   {
#     "\"average age of costars\"": "average age of costars"
#   },
#   {
#     "@@avg_age": 63.79411764705883
#   }
# ]

# %%
#CREATE LOADING JOBs
results = conn.gsql('''
USE GRAPH movie_graph
BEGIN
DROP JOB py_job_movies
CREATE LOADING JOB py_job_movies FOR GRAPH movie_graph {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX movie VALUES($0, $1, $2) USING SEPARATOR=";", HEADER="true", EOL="\n", QUOTE="double";
    }
END''')
print(results)

results = conn.gsql('''
USE GRAPH movie_graph
BEGIN
DROP JOB py_job_persons
CREATE LOADING JOB py_job_persons FOR GRAPH movie_graph {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO VERTEX person VALUES($0, $1) USING SEPARATOR=";", HEADER="true", EOL="\n", QUOTE="double";
    }
END''')
print(results)


results = conn.gsql('''
USE GRAPH movie_graph
BEGIN
DROP JOB py_job_acted_in
CREATE LOADING JOB py_job_acted_in FOR GRAPH movie_graph {
      DEFINE FILENAME MyDataSource;
      LOAD MyDataSource TO EDGE ACTED_IN VALUES($0, $1) USING SEPARATOR=";", HEADER="true", EOL="\n", QUOTE="double";
    }
END''')
print(results)

print(conn.graphname)
conn.gsql("USE GRAPH movie_graph")
results = conn.gsql('''USE GRAPH movie_graph
    SHOW JOB *''')
print(results)

print(conn.gsql("LS"))
# Out:
# Using graph 'movie_graph'
# Successfully dropped jobs on the graph 'movie_graph': [py_job_movies].
# Successfully created loading jobs: [py_job_movies].
# Using graph 'movie_graph'
# Successfully dropped jobs on the graph 'movie_graph': [py_job_persons].
# Successfully created loading jobs: [py_job_persons].
# Using graph 'movie_graph'
# Successfully dropped jobs on the graph 'movie_graph': [py_job_acted_in].
# Successfully created loading jobs: [py_job_acted_in].
# movie_graph
# Using graph 'movie_graph'
#   - CREATE LOADING JOB py_job_movies FOR GRAPH movie_graph {
#       DEFINE FILENAME MyDataSource;
#       LOAD MyDataSource TO VERTEX movie VALUES($0, $1, $2) USING SEPARATOR=";", HEADER="true", EOL="
# ", QUOTE="double";
#     }
#
#   - CREATE LOADING JOB py_job_persons FOR GRAPH movie_graph {
#       DEFINE FILENAME MyDataSource;
#       LOAD MyDataSource TO VERTEX person VALUES($0, $1) USING SEPARATOR=";", HEADER="true", EOL="
# ", QUOTE="double";
#     }
#
#   - CREATE LOADING JOB py_job_acted_in FOR GRAPH movie_graph {
#       DEFINE FILENAME MyDataSource;
#       LOAD MyDataSource TO EDGE ACTED_IN VALUES($0, $1) USING SEPARATOR=";", HEADER="true", EOL="
# ", QUOTE="double";
#     }
#
# ---- Global vertices, edges, and all graphs
# Vertex Types:
#   - VERTEX person(PRIMARY_ID name STRING, born DATETIME) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
#   - VERTEX movie(PRIMARY_ID title STRING, tagline STRING, released DATETIME) WITH STATS="OUTDEGREE_BY_EDGETYPE", PRIMARY_ID_AS_ATTRIBUTE="true"
# Edge Types:
#   - UNDIRECTED EDGE ACTED_IN(FROM person, TO movie)
#   - UNDIRECTED EDGE DIRECTED(FROM person, TO movie)
#   - UNDIRECTED EDGE FRIEND(FROM person, TO person)
#
# Graphs:
#   - Graph movie_graph(person:v, movie:v, ACTED_IN:e, DIRECTED:e, FRIEND:e)
# Jobs:
#
#
# JSON API version: v2
# Syntax version: v2

# %%
#RUN LOADING JOBs
dataSource = "/content/knowledge_graph_using_tigergraph/data/movies.csv"
results = conn.gsql('''
USE GRAPH movie_graph
RUN LOADING JOB py_job_movies USING MyDataSource="'+dataSource+'"
''')
print(results)
# Out:
# ---------------------------------------------------------------------------
# TigerGraphException                       Traceback (most recent call last)
# <ipython-input-54-b65000c1c30d> in <cell line: 2>()
#       1 dataSource = "/content/knowledge_graph_using_tigergraph/data/movies.csv"
# ----> 2 results = conn.gsql('''
#       3 USE GRAPH movie_graph
#       4 RUN LOADING JOB py_job_movies USING MyDataSource="'+dataSource+'"
#       5 ''')
#
# /usr/local/lib/python3.10/dist-packages/pyTigerGraph/pyTigerGraphGSQL.py in gsql(self, query, graphname, options)
#      86             ret = clean_res(res.splitlines())
#      87
# ---> 88         check_error(query, ret)
#      89
#      90         string_without_ansi = ANSI_ESCAPE.sub('', ret)
#
# /usr/local/lib/python3.10/dist-packages/pyTigerGraph/pyTigerGraphGSQL.py in check_error(query, resp)
#      60             if "RUN LOADING JOB" in query.upper():
#      61                 if "LOAD SUCCESSFUL to TigerGraph" not in resp:
# ---> 62                     raise TigerGraphException(resp)
#      63
#      64         def clean_res(resp: list) -> str:
#
# TigerGraphException: Using graph 'movie_graph'
# Semantic Check Fails: TigerGraph sensitive directory '/home/tigergraph/tigergraph/app' is not allowed in path '/home/tigergraph/tigergraph/app/3.10.0/dev/gdk/gsql/'+dataSource+''. Please use another path.

# %%
#RUN LOADING JOBs
f_movies =  "/content/knowledge_graph_using_tigergraph/data/movies.csv"
f_persons = "/content/knowledge_graph_using_tigergraph/data/actors.csv"
f_acted_in = "/content/knowledge_graph_using_tigergraph/data/acted_in.csv"

res = conn.runLoadingJobWithFile(filePath=f_movies, fileTag='file_movies', jobName='py_job_movies', sep=";")
print(json.dumps(res, indent=2))
res = conn.runLoadingJobWithFile(filePath=f_persons, fileTag='file_persons', jobName='py_job_persons', sep=";")
print(json.dumps(res, indent=2))
res = conn.runLoadingJobWithFile(filePath=f_acted_in, fileTag='file_acted_in', jobName='py_job_acted_in', sep=";")
print(json.dumps(res, indent=2))
# Out:
# ---------------------------------------------------------------------------
# TigerGraphException                       Traceback (most recent call last)
# <ipython-input-56-35e3ad290ad6> in <cell line: 5>()
#       3 f_acted_in="/content/knowledge_graph_using_tigergraph/data/acted_in.csv"
#       4
# ----> 5 res = conn.runLoadingJobWithFile(filePath=f_movies, fileTag='file_movies', jobName='py_job_movies', sep=";")
#       6 print(json.dumps(res, indent=2))
#       7 res = conn.runLoadingJobWithFile(filePath=f_persons, fileTag='file_persons', jobName='py_job_persons', sep=";")
#
# /usr/local/lib/python3.10/dist-packages/pyTigerGraph/pyTigerGraphLoading.py in runLoadingJobWithFile(self, filePath, fileTag, jobName, sep, eol, timeout, sizeLimit)
#      67             # TODO Should throw exception instead?
#      68
# ---> 69         res = self._post(self.restppUrl + "/ddl/" + self.graphname, params=params, data=data,
#      70             headers={"RESPONSE-LIMIT": str(sizeLimit), "GSQL-TIMEOUT": str(timeout)})
#      71
#
# /usr/local/lib/python3.10/dist-packages/pyTigerGraph/pyTigerGraphBase.py in _post(self, url, authMode, headers, data, resKey, skipCheck, params, jsonData)
#     381             logger.debug("params: " + self._locals(locals()))
#     382
# --> 383         res = self._req("POST", url, authMode, headers, data, resKey, skipCheck, params, jsonData=jsonData)
#     384
#     385         if logger.level == logging.DEBUG:
#
# /usr/local/lib/python3.10/dist-packages/pyTigerGraph/pyTigerGraphBase.py in _req(self, method, url, authMode, headers, data, resKey, skipCheck, params, strictJson, jsonData, jsonResponse)
#     304
#     305         if not skipCheck:
# --> 306             self._errorCheck(res)
#     307         if not resKey:
#     308             if logger.level == logging.DEBUG:
#
# /usr/local/lib/python3.10/dist-packages/pyTigerGraph/pyTigerGraphBase.py in _errorCheck(self, res)
#     220         if "error" in res and res["error"] and res["error"] != "false":
#     221             # Endpoint might return string "false" rather than Boolean false
# --> 222             raise TigerGraphException(res["message"], (res["code"] if "code" in res else None))
#     223
#     224     def _req(self, method: str, url: str, authMode: str = "token", headers: dict = None,
#
# TigerGraphException: ('Exception in OnFinish: GetResult index out of range, index: 0 | response_datas_.size()0', 'REST-10005')
